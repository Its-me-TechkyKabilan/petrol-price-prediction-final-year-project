# %%
# %pip install tensorflow autokeras statsmodels prophet xgboost scikit-learn pandas numpy matplotlib keras-tuner plotly nbformat ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\agass\appdata\roaming\python\python311\site-packages (2.19.0)
# Requirement already satisfied: autokeras in c:\users\agass\appdata\roaming\python\python311\site-packages (2.0.0)
# Requirement already satisfied: statsmodels in c:\users\agass\appdata\roaming\python\python311\site-packages (0.14.5)
# Requirement already satisfied: prophet in c:\users\agass\appdata\roaming\python\python311\site-packages (1.1.7)
# Requirement already satisfied: xgboost in c:\users\agass\appdata\roaming\python\python311\site-packages (3.0.2)
# Requirement already satisfied: scikit-learn in c:\users\agass\appdata\roaming\python\python311\site-packages (1.7.1)
# Requirement already satisfied: pandas in c:\users\agass\appdata\roaming\python\python311\site-packages (2.3.1)
# Requirement already satisfied: numpy in c:\users\agass\appdata\roaming\python\python311\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\agass\appdata\roaming\python\python311\site-packages (3.10.3)
# Requirement already satisfied: keras-tuner in c:\users\agass\appdata\roaming\python\python311\site-packages (1.4.7)
# Requirement already satisfied: plotly in c:\users\agass\appdata\roaming\python\python311\site-packages (6.2.0)
# Requirement already satisfied: nbformat in c:\users\agass\appdata\roaming\python\python311\site-packages (5.10.4)
# Requirement already satisfied: ipywidgets in c:\users\agass\appdata\roaming\python\python311\site-packages (8.1.7)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in c:\program files\python311\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: keras-nlp>=0.8.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from autokeras) (0.21.1)
# Requirement already satisfied: dm-tree in c:\users\agass\appdata\roaming\python\python311\site-packages (from autokeras) (0.1.9)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\agass\appdata\roaming\python\python311\site-packages (from statsmodels) (1.16.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\agass\appdata\roaming\python\python311\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\agass\appdata\roaming\python\python311\site-packages (from prophet) (1.2.5)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\agass\appdata\roaming\python\python311\site-packages (from prophet) (0.76)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in c:\users\agass\appdata\roaming\python\python311\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\agass\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\agass\appdata\roaming\python\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\agass\appdata\roaming\python\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\agass\appdata\roaming\python\python311\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: kt-legacy in c:\users\agass\appdata\roaming\python\python311\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from plotly) (1.47.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\agass\appdata\roaming\python\python311\site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\agass\appdata\roaming\python\python311\site-packages (from nbformat) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\agass\appdata\roaming\python\python311\site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipywidgets) (9.4.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: colorama in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\agass\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\agass\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\agass\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from jsonschema>=2.6->nbformat) (0.26.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\agass\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\agass\appdata\roaming\python\python311\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (311)
# Requirement already satisfied: rich in c:\users\agass\appdata\roaming\python\python311\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in c:\users\agass\appdata\roaming\python\python311\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\agass\appdata\roaming\python\python311\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: keras-hub==0.21.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from keras-nlp>=0.8.0->autokeras) (0.21.1)
# Requirement already satisfied: regex in c:\users\agass\appdata\roaming\python\python311\site-packages (from keras-hub==0.21.1->keras-nlp>=0.8.0->autokeras) (2024.11.6)
# Requirement already satisfied: kagglehub in c:\users\agass\appdata\roaming\python\python311\site-packages (from keras-hub==0.21.1->keras-nlp>=0.8.0->autokeras) (0.3.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\agass\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agass\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agass\appdata\roaming\python\python311\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\agass\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\agass\appdata\roaming\python\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\agass\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\agass\appdata\roaming\python\python311\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\agass\appdata\roaming\python\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: pyyaml in c:\users\agass\appdata\roaming\python\python311\site-packages (from kagglehub->keras-hub==0.21.1->keras-nlp>=0.8.0->autokeras) (6.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python311\python.exe

# %%
# %%
# Cell 1: Header and Dependencies
"""
Petrol Price Prediction Ensemble Forecast Notebook

Standalone Jupyter-style notebook split into cells,
for training, forecasting, and optional test-set evaluation.

Dependencies (install in Cell 0):
    tensorflow, autokeras, statsmodels, prophet, xgboost,
    scikit-learn, pandas, numpy, matplotlib, keras-tuner

USAGE as script:
    python petrol_price_prediction.py --train_file "D:/Kabilan/Final Year Project/train_data.csv" \
      --test_file "D:/Kabilan/Final Year Project/test_data.csv" --output_file "D:/Kabilan/Final Year Project/forecast_petrol_prices.csv"
"""
import os  # for file existence checks
import tensorflow as tf
import argparse
import pandas as pd
import numpy as npw
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import keras_tuner as kt
from statsmodels.tsa.arima.model import ARIMA
from prophet import Prophet
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
import plotly.graph_objects as go

# %%
# Cell 2: Argument Parsing and Helper Functions

import argparse
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
import keras_tuner as kt

def parse_args():
    parser = argparse.ArgumentParser(
        description="Super Hyper Realistic Petrol Price Predictor (Ensemble)"
    )
    parser.add_argument('--train_file',    type=str, default='train_data.csv',            help='Path to training CSV')
    parser.add_argument('--test_file',     type=str, default=None,                        help='Optional test CSV')
    parser.add_argument('--output_file',   type=str, default='forecast_petrol_prices.csv', help='Output CSV')
    parser.add_argument('--start_date',    type=str, default='1990-01-01',               help='Training start')
    parser.add_argument('--end_date',      type=str, default='2025-03-10',               help='Training end')
    parser.add_argument('--forecast_start',type=str, default='2025-03-11',               help='Forecast start')
    parser.add_argument('--forecast_end',  type=str, default='2025-12-31',               help='Forecast end')
    # Ignore Jupyter args
    args, _ = parser.parse_known_args()
    return args

def create_dataset(dataset: np.ndarray, time_step: int):
    X, Y = [], []
    for i in range(len(dataset) - time_step):
        X.append(dataset[i:i+time_step, 0])
        Y.append(dataset[i+time_step, 0])
    return np.array(X), np.array(Y)

def build_lstm_model(time_step, hp):
    model = Sequential()
    model.add(LSTM(units=hp.Int('lstm_units_1', 32, 256, 32),
                   return_sequences=True,
                   input_shape=(time_step, 1)))
    model.add(Dropout(rate=hp.Float('dropout_1', 0.0, 0.5, 0.1)))
    model.add(LSTM(units=hp.Int('lstm_units_2', 32, 256, 32),
                   return_sequences=True))
    model.add(Dropout(rate=hp.Float('dropout_2', 0.0, 0.5, 0.1)))
    model.add(LSTM(units=hp.Int('lstm_units_3', 32, 256, 32)))
    model.add(Dropout(rate=hp.Float('dropout_3', 0.0, 0.5, 0.1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def recursive_forecast_reg(model, last_window, steps):
    preds = []
    window = last_window.copy()
    for _ in range(steps):
        p = model.predict(window.reshape(1, -1))[0]
        preds.append(p)
        window = np.append(window[1:], p)
    return np.array(preds)

# %%
# Cell 2.5: Notebook Arguments Override
class Args: pass
args = Args()
# If the CSVs live alongside this notebook, use:
args.train_file     = "train_data.csv"
args.test_file      = "test_data.csv"
args.output_file    = "forecast_petrol_prices.csv"
args.start_date     = "1990-01-01"
args.end_date       = "2025-05-05"
args.forecast_start = "2025-05-05"
args.forecast_end   = "2025-05-30"

# %%
# %%
# Cell 3: Main Script - Load and Preprocess Data
# (args defined in Cell 2.5)
import glob
# Auto-detect the correct training file by scanning for CSV/TXT with 'Petrol (USD)' column
search_dir = os.path.dirname(args.train_file) or os.getcwd()
candidates = glob.glob(os.path.join(search_dir, '*.csv')) + glob.glob(os.path.join(search_dir, '*.txt'))
train_path = None
for file in candidates:
    try:
        temp_df = pd.read_csv(file, nrows=5)
        if 'Petrol (USD)' in temp_df.columns or 'Petrol' in temp_df.columns:
            train_path = file
            print(f"Detected training file: {train_path}")
            break
    except Exception:
        continue
if not train_path:
    raise FileNotFoundError(f"No suitable training file found in {search_dir}")

# Load training data
df = pd.read_csv(train_path)
# Rename and prepare
if 'Petrol (USD)' in df.columns:
    df = df.rename(columns={'Petrol (USD)': 'Petrol'})
elif 'Petrol' in df.columns:
    df = df.rename(columns={'Petrol': 'Petrol'})
else:
    raise KeyError("Dataset does not contain 'Petrol' column.")
df = df.dropna(subset=['Petrol'])
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
df = df.sort_values('Date')
mask = (df['Date'] >= args.start_date) & (df['Date'] <= args.end_date)
df = df.loc[mask].reset_index(drop=True)

# Extract & scale
data = df['Petrol'].values.reshape(-1, 1)
scaler = MinMaxScaler((0, 1))
data_scaled = scaler.fit_transform(data)

# Create lagged features
time_step = 60
X_lstm, y_lstm = create_dataset(data_scaled, time_step)
X_lstm = X_lstm.reshape(-1, time_step, 1)
X_reg, y_reg = create_dataset(data_scaled, time_step)

# %%
time_step = 60
X_lstm, y_lstm = create_dataset(data_scaled, time_step)
X_lstm = X_lstm.reshape(-1, time_step, 1)
X_reg, y_reg = create_dataset(data_scaled, time_step)
# Out:
# Detected training file: d:\Kabilan's\Final Year Project\train_data.csv

# %%
# %%
# Cell 4: Hyperparameter Tuning for LSTM
split = int(len(X_lstm) * 0.9)
tuner = kt.RandomSearch(lambda hp: build_lstm_model(time_step, hp), 'val_loss', max_trials=10, executions_per_trial=1, directory='kt_dir', project_name='petrol')
tuner.search(X_lstm[:split], y_lstm[:split], validation_data=(X_lstm[split:], y_lstm[split:]), epochs=50, batch_size=32)
best_lstm = tuner.get_best_models(1)[0]
# Out:
# Reloading Tuner from kt_dir\petrol\tuner0.json
# WARNING:tensorflow:From C:\Users\agass\AppData\Roaming\Python\Python311\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# C:\Users\agass\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Users\agass\AppData\Roaming\Python\Python311\site-packages\keras\src\saving\saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 24 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# %%
# Cell 5: Train Base LSTM & Forecast
best_lstm.fit(X_lstm, y_lstm, epochs=50, batch_size=32)
forecast_dates = pd.date_range(start=args.forecast_start, end=args.forecast_end)
steps = len(forecast_dates)
seq = data_scaled[-time_step:].copy()
lstm_preds = []
for _ in range(steps):
    p = best_lstm.predict(seq.reshape(1, time_step,1))[0,0]
    lstm_preds.append(p)
    seq = np.append(seq, [[p]], axis=0)[1:]
lstm_forecast = scaler.inverse_transform(np.array(lstm_preds).reshape(-1,1))
# Out:
# Epoch 1/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 113ms/step - loss: 0.0012
# Epoch 2/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 105ms/step - loss: 4.8376e-04
# Epoch 3/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - loss: 6.2582e-04
# Epoch 4/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 122ms/step - loss: 4.9468e-04
# Epoch 5/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - loss: 4.9803e-04
# Epoch 6/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - loss: 5.5666e-04
# Epoch 7/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - loss: 4.9698e-04
# Epoch 8/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 6.2544e-04
# Epoch 9/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - loss: 5.0114e-04
# Epoch 10/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 9s 128ms/step - loss: 4.7630e-04
# Epoch 11/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - loss: 4.6877e-04
# Epoch 12/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 122ms/step - loss: 4.0427e-04
# Epoch 13/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - loss: 4.0760e-04
# Epoch 14/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - loss: 4.2163e-04
# Epoch 15/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 121ms/step - loss: 6.6428e-04
# Epoch 16/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - loss: 4.2379e-04
# Epoch 17/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - loss: 4.7081e-04
# Epoch 18/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - loss: 3.9617e-04
# Epoch 19/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 4.7222e-04
# Epoch 20/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - loss: 3.8043e-04
# Epoch 21/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - loss: 3.9682e-04
# Epoch 22/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 128ms/step - loss: 3.6827e-04
# Epoch 23/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - loss: 4.2452e-04
# Epoch 24/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - loss: 3.7266e-04
# Epoch 25/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - loss: 3.5928e-04
# Epoch 26/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - loss: 3.6411e-04
# Epoch 27/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - loss: 3.6332e-04
# Epoch 28/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 4.2684e-04
# Epoch 29/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - loss: 4.6452e-04
# Epoch 30/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 123ms/step - loss: 3.8688e-04
# Epoch 31/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - loss: 3.6742e-04
# Epoch 32/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - loss: 3.6003e-04
# Epoch 33/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 112ms/step - loss: 2.9957e-04
# Epoch 34/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - loss: 3.0810e-04
# Epoch 35/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 3.9229e-04
# Epoch 36/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 142ms/step - loss: 3.4104e-04
# Epoch 37/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 149ms/step - loss: 3.0999e-04
# Epoch 38/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 8s 136ms/step - loss: 4.4711e-04
# Epoch 39/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - loss: 3.4946e-04
# Epoch 40/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - loss: 3.4015e-04
# Epoch 41/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 123ms/step - loss: 3.2630e-04
# Epoch 42/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 120ms/step - loss: 3.2609e-04
# Epoch 43/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - loss: 3.2458e-04
# Epoch 44/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - loss: 3.0907e-04
# Epoch 45/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - loss: 3.0862e-04
# Epoch 46/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - loss: 3.5125e-04
# Epoch 47/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - loss: 3.1746e-04
# Epoch 48/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - loss: 2.9181e-04
# Epoch 49/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - loss: 3.0769e-04
# Epoch 50/50
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - loss: 2.9387e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
# %%
# Cell 6: ARIMA, Prophet & Regression Forecasts
# ARIMA
arima = ARIMA(df['Petrol'], order=(5,1,0)).fit()
arima_f = arima.forecast(steps=steps).values.reshape(-1,1)
# Prophet
df_prop = df.rename(columns={'Date':'ds','Petrol':'y'})[['ds','y']]
prophet = Prophet().fit(df_prop)
fut = prophet.make_future_dataframe(periods=steps)
prophet_f = prophet.predict(fut)['yhat'][-steps:].values.reshape(-1,1)
# Regression Models
models = {
    'XGB': XGBRegressor(n_estimators=100).fit(X_reg, y_reg),
    'RF': RandomForestRegressor(n_estimators=100).fit(X_reg, y_reg),
    'SVR': SVR().fit(X_reg, y_reg.ravel()),
    'LR': LinearRegression().fit(X_reg, y_reg)
}
last_win = data_scaled[-time_step:].flatten()
reg_preds = {name: scaler.inverse_transform(recursive_forecast_reg(m, last_win, steps).reshape(-1,1)) for name,m in models.items()}
# Out:
# 18:51:30 - cmdstanpy - INFO - Chain [1] start processing
# 18:51:31 - cmdstanpy - INFO - Chain [1] done processing

# %%
# %%
# Cell 7: Ensemble & Optional Test Evaluation
all_preds = np.hstack([lstm_forecast, arima_f, prophet_f] + list(reg_preds.values()))
ensemble = all_preds.dot(np.ones((len(models) + 3, 1)) / (len(models) + 3))

if args.test_file:
    # Auto-detect or skip missing test file
    test_path = args.test_file
    if not os.path.isfile(test_path):
        base = os.path.basename(test_path).split('.')[0]
        search_dir = os.path.dirname(test_path) or os.getcwd()
        candidates = glob.glob(os.path.join(search_dir, f"{base}*.csv"))
        if candidates:
            print(f"Auto-detected test file: {candidates[0]}")
            test_path = candidates[0]
        else:
            print(f"Test file not found at {test_path}. Skipping test evaluation.")
            test_path = None
    if test_path:
        test_df = pd.read_csv(test_path)
        # Rename and prepare test data
        if 'Petrol (USD)' in test_df.columns:
            test_df = test_df.rename(columns={'Petrol (USD)': 'Petrol'})
        elif 'Prediction' in test_df.columns:
            # use 'Prediction' as actual petrol values
            test_df = test_df.rename(columns={'Prediction': 'Petrol'})
        elif 'Petrol' not in test_df.columns:
            raise KeyError("Test data does not contain 'Petrol' or 'Prediction' column.")
        test_df = test_df.dropna(subset=['Petrol'])
        test_df['Date'] = pd.to_datetime(test_df['Date'], errors='coerce')
        vals = test_df.sort_values('Date')['Petrol'].values.reshape(-1, 1)
        scaled_vals = scaler.transform(vals)
        X_t, y_t = create_dataset(scaled_vals, time_step)
        rmse = lambda preds: np.sqrt(mean_squared_error(vals[time_step:], preds.flatten()))
        print('LSTM Test RMSE:', rmse(scaler.inverse_transform(best_lstm.predict(X_t.reshape(-1, time_step, 1)))))
        for nm, m in models.items():
            pr = scaler.inverse_transform(
                recursive_forecast_reg(m, scaled_vals[-time_step:].flatten(), len(y_t)).reshape(-1, 1)
            )
            print(f"{nm} Test RMSE: {rmse(pr):.3f}")
# %%():
            pr = scaler.inverse_transform(
                recursive_forecast_reg(m, scaled_vals[-time_step:].flatten(), len(y_t)).reshape(-1, 1)
            )
            print(f"{nm} Test RMSE: {rmse(pr):.3f}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
# LSTM Test RMSE: 0.129178012917996
# XGB Test RMSE: 0.191
# XGB Test RMSE: 0.191
# RF Test RMSE: 0.198
# RF Test RMSE: 0.198
# SVR Test RMSE: 0.331
# SVR Test RMSE: 0.331
# LR Test RMSE: 0.330
# LR Test RMSE: 0.330

# %%
# %%
# Cell 8: Interactive Plot & Table
# Prepare in-sample LSTM series for plotting
train_pred   = scaler.inverse_transform(best_lstm.predict(X_lstm))
train_dates  = df['Date'][time_step:]

fig=go.Figure()
fig.add_trace(go.Scatter(x=df['Date'],y=data.flatten(),mode='lines',name='Original'))
fig.add_trace(go.Scatter(x=train_dates,y=train_pred.flatten(),mode='lines',name='LSTM In-Sample'))
fig.add_trace(go.Scatter(x=forecast_dates,y=ensemble.flatten(),mode='lines',name='Ensemble Forecast'))
fig.update_layout(
    title='Petrol Price Prediction',
    xaxis=dict(rangeselector=dict(buttons=[dict(count=1,label='1m',step='month',stepmode='backward'),dict(count=6,label='6m',step='month',stepmode='backward'),dict(count=1,label='Y',step='year',stepmode='backward'),dict(count=5,label='5y',step='year',stepmode='backward'),dict(step='all')]),rangeslider=dict(visible=True),type='date'),
    yaxis=dict(title='Petrol Price (USD)')
)
fig.show()

forecast_df=pd.DataFrame({'Date':forecast_dates,'Predicted Petrol Price (USD)':ensemble.flatten()})
forecast_df.to_csv(args.output_file,index=False)
print("\nEnsemble Forecast Table:")
print(forecast_df.to_string(index=False))
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step
# Ensemble Forecast Table:
#       Date  Predicted Petrol Price (USD)
# 2025-05-05                      3.133849
# 2025-05-06                      3.150037
# 2025-05-07                      3.161333
# 2025-05-08                      3.168448
# 2025-05-09                      3.177949
# 2025-05-10                      3.189814
# 2025-05-11                      3.203545
# 2025-05-12                      3.215075
# 2025-05-13                      3.224586
# 2025-05-14                      3.234211
# 2025-05-15                      3.244340
# 2025-05-16                      3.255197
# 2025-05-17                      3.267048
# 2025-05-18                      3.279953
# 2025-05-19                      3.288173
# 2025-05-20                      3.298700
# 2025-05-21                      3.308473
# 2025-05-22                      3.317628
# 2025-05-23                      3.327757
# 2025-05-24                      3.335473
# 2025-05-25                      3.342421
# 2025-05-26                      3.349105
# 2025-05-27                      3.353724
# 2025-05-28                      3.360602
# 2025-05-29                      3.372632
# 2025-05-30                      3.377599
